# %%
# 1. 克隆项目（只需执行一次，已克隆可跳过）
# !git clone https://github.com/liushuang-118/Universal-Guided-Diffusion.git
# Out:
# Cloning into 'Universal-Guided-Diffusion'...
# remote: Enumerating objects: 503, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 503 (delta 71), reused 61 (delta 55), pack-reused 411 (from 1)
# Receiving objects: 100% (503/503), 76.19 MiB | 49.25 MiB/s, done.
# Resolving deltas: 100% (166/166), done.

# %%
# 2. 挂载 Google Drive（每次运行都需要）
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 3. 进入项目目录
# %cd /content/Universal-Guided-Diffusion/stable-diffusion-guided
# Out:
# /content/Universal-Guided-Diffusion/stable-diffusion-guided

# %%
# 安装 PyTorch 2.0+ (CUDA 11.8) 与 torchvision
# !pip install --upgrade torch torchvision --index-url https://download.pytorch.org/whl/cu118

# 安装 Stable Diffusion 所需依赖（避开无法解析的 pytorch-lightning==1.6.5）
# !pip install --upgrade \
    omegaconf \
    einops \
    transformers==4.19.2 \
    diffusers \
    invisible-watermark

# 降级 pip 到 23.2（兼容旧版 pytorch_lightning）
# !pip install pip==23.2.1

# 安装 pytorch_lightning==1.6.5
# !pip install pytorch_lightning==1.6.5

# 如果你要安装当前目录的项目为可编辑模式（确保当前目录有 setup.py）
# !pip install -e .
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# DEPRECATION: pytorch-lightning 1.6.5 has a non-standard dependency specifier torch>=1.8.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...
#   Obtaining dependency information for transformers==4.19.2 from https://files.pythonhosted.org/packages/52/82/b62f139e77c70fab2763d99d83a77a27a179502430851144a1765e37f5ad/transformers-4.19.2-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 2.4 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for invisible-watermark from https://files.pythonhosted.org/packages/2b/57/18b5a914f6d7994dd349252873169e946dc824328e9a37fd15ed836deedc/invisible_watermark-0.2.0-py3-none-any.whl.metadata
# ...

# %%
# 6. 安装 taming-transformers（只需执行一次，已装可跳过）
# !git clone https://github.com/CompVis/taming-transformers.git
# %cd taming-transformers
# !pip install -e .

# 7. 安装 OpenAI CLIP（Stable Diffusion 用到）
# !pip install git+https://github.com/openai/CLIP.git

# 8. 安装 Kornia（图像处理库）
# !pip install kornia
# Out:
# Cloning into 'taming-transformers'...
# remote: Enumerating objects: 1342, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1342 (delta 0), reused 0 (delta 0), pack-reused 1341 (from 2)
# Receiving objects: 100% (1342/1342), 409.77 MiB | 50.32 MiB/s, done.
# Resolving deltas: 100% (282/282), done.
# /content/Universal-Guided-Diffusion/stable-diffusion-guided/taming-transformers
# Obtaining file:///content/Universal-Guided-Diffusion/stable-diffusion-guided/taming-transformers
#   Preparing metadata (setup.py) ... done
# ...
# DEPRECATION: pytorch-lightning 1.6.5 has a non-standard dependency specifier torch>=1.8.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...
#   Running setup.py develop for taming-transformers
# ...

# %%
# !pip install omegaconf --upgrade
# Out:
# ...
# DEPRECATION: pytorch-lightning 1.6.5 has a non-standard dependency specifier torch>=1.8.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install GPUtil
# Out:
# ...
# DEPRECATION: pytorch-lightning 1.6.5 has a non-standard dependency specifier torch>=1.8.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# %cd /content/Universal-Guided-Diffusion/stable-diffusion-guided

# 10. 添加 taming 模块路径（只需要添加一次）
# !cp -r taming-transformers/taming ./taming

# 11. 设置 PYTHONPATH（每次运行都推荐设置）
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# Out:
# /content/Universal-Guided-Diffusion/stable-diffusion-guided

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 424 bytes | 212.00 KiB/s, done.
# From https://github.com/liushuang-118/Universal-Guided-Diffusion
#    e350f0e..4bb2bc6  main       -> origin/main
# Updating e350f0e..4bb2bc6
# Fast-forward
#  stable-diffusion-guided/scripts/object_detection_with_evaluation.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !rm -rf /content/Universal-Guided-Diffusion/stable-diffusion-guided/test_od

# %%
# !mkdir -p test_od

# !python scripts/object_detection_with_evaluation.py \
  --indexes 0 \
  --text "a headshot of a woman with a dog" \
  --scale 1.5 \
  --optim_forward_guidance \
  --optim_num_steps 5 \
  --optim_forward_guidance_wt 100 \
  --optim_original_conditioning \
  --ddim_steps 50 \
  --optim_folder ./test_od/ \
  --ckpt /content/drive/MyDrive/sd-v1-4.ckpt \
  --trials 3
# Out:
# ['/content/Universal-Guided-Diffusion/stable-diffusion-guided/scripts', '/env/python', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '/usr/local/lib/python3.11/dist-packages', '/content/Universal-Guided-Diffusion/stable-diffusion-guided', '/content/Universal-Guided-Diffusion/stable-diffusion-guided/taming-transformers', '/usr/lib/python3/dist-packages', '/content/Universal-Guided-Diffusion/stable-diffusion-guided']
# 2025-05-23 02:10:04.893209: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-23 02:10:04.911378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !mkdir -p test_od

# !python scripts/object_detection_with_evaluation.py \
  --indexes 0 \
  --text "a headshot of a woman with a dog" \
  --scale 1.5 \
  --optim_backward_guidance \
  --optim_num_steps 5 \
  --optim_forward_guidance_wt 100 \
  --optim_original_conditioning \
  --ddim_steps 50 \
  --optim_folder ./test_od/ \
  --ckpt /content/drive/MyDrive/sd-v1-4.ckpt \
  --trials 6
# Out:
# ['/content/Universal-Guided-Diffusion/stable-diffusion-guided/scripts', '/env/python', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '/usr/local/lib/python3.11/dist-packages', '/content/Universal-Guided-Diffusion/stable-diffusion-guided', '/content/Universal-Guided-Diffusion/stable-diffusion-guided/taming-transformers', '/usr/lib/python3/dist-packages', '/content/Universal-Guided-Diffusion/stable-diffusion-guided']
# 2025-05-23 02:22:10.974151: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-23 02:22:10.992515: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
